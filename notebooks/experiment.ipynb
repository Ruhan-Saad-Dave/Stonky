# %%
import yfinance as yf 
import pandas as pd

df = yf.download("GOOG", period = "1y", interval = "1d")
columns = [col[0] for col in df.columns]
df = pd.DataFrame(df.values, columns = columns, index = df.index)
df.to_csv(r"data/GOOG.csv")

# %%
import yfinance as yf
import pandas as pd

df = yf.Ticker("GOOG").history(period = "1y", interval = "1d")
df = df.reset_index()
df["Date"] = df["Date"].dt.strftime("%Y-%m-%d")
df = df.drop(columns = ["Dividends", "Stock Splits"])
df
# Out:
#            Date        Open        High         Low       Close    Volume
# 0    2024-07-03  185.409901  186.723587  184.499265  186.494690   7409100
# 1    2024-07-05  186.425031  191.341416  186.425031  191.042862  14303400
# 2    2024-07-08  190.450697  190.763192  188.415470  189.569916  12097600
# 3    2024-07-09  190.833860  191.938557  189.321118  189.530121  10198500
# 4    2024-07-10  189.838639  192.386406  189.709255  191.739517  12052900
# ..          ...         ...         ...         ...         ...       ...
# 245  2025-06-26  173.384995  174.649994  170.860001  174.429993  25909100
# 246  2025-06-27  174.630005  178.839996  172.710007  178.270004  74053100
# 247  2025-06-30  180.785004  181.580002  175.500000  177.389999  43964600
# 248  2025-07-01  176.804993  177.220001  174.660004  176.910004  25778500
# 249  2025-07-02  176.544998  179.934998  176.089996  179.759995  19300400
#
# [250 rows x 6 columns]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

FEATURES = ["Open", "High", "Low", "Close", "Volume"]
df = pd.read_csv(r".\data\GOOG.csv")
df = df[FEATURES]
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(df)
scaled_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 5
#       2 from sklearn.preprocessing import MinMaxScaler
#       4 FEATURES = ["Open", "High", "Low", "Close", "Volume"]
# ----> 5 df = pd.read_csv(r".\data\GOOG.csv")
#       6 df = df[FEATURES]
#       7 scaler = MinMaxScaler()
#
# ...
